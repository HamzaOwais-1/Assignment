# %% [markdown]
# 1.Write a program that print the numbers from 1 to 10 using loop

# %%
for i in range(10):
    i = i +1
    print(i)

# %% [markdown]
# 2. Write a program to print even numbers from 1 to 10.

# %%
for num in range(10):
    num = num + 1
    if num % 2 == 0:
        print(num)

# %% [markdown]
# 3. Write a program that prints 'Happy Birthday!' five times on screen.

# %%
for wish in range(5):
    print("Happy Birthday")

# %% [markdown]
# 4. Write a program that takes a number n as input from the user and generates the first
# n terms of the series formed by squaring the natural numbers.
# Sample output
# Enter a number: 6
# The first 6 terms of the series are:
# 1 4 9 16 25 36

# %%
user = int(input("Enter a number"))
for square in range(user):
    square = square + 1
    print(square**2)

# %% [markdown]
# 5. Write a program that prompts the user to input a number and prints its multiplication
# table.

# %%
table = int(input("To generate a table, Enter a number"))
times = int(input("Enter number of times to print table"))

for i in range(times):
    i = i + 1
    print(f"{table} * {i} = {table * i}")

# %% [markdown]
# 6. Write a program that prompts the user to enter a number n, and then prints all the
# odd numbers between 1 and n.

# %%
odd = int(input("Enter  a number till where the odd number should print"))

for j in range(odd):
    if j % 2 != 0:
        print(j)

# %% [markdown]
# 7. Write a Python program to print the numbers from 20 to 1 using a while loop.

# %%
number = 20

while number >= 1:
    print(number)
    number = number - 1

# %% [markdown]
# 8. Write a program that prompts the user to enter a number n and prints all the
# numbers from 1 to n.

# %%
user = int(input("Enter a number till where to print all number from 1"))

for k in range(out):
    k = k + 1
    print(k)

# %% [markdown]
# 9. Write a program that prompts the user to enter a number and repeats this process 5
# times. The program should accumulate the numbers entered and then display the final
# running total.
# - Sample Output:
# - Enter a number: 10
# - Enter a number: 15
# - Enter a number: 35
# - Enter a number: 40
# - Enter a number: 50
# - The final running total is: 150

# %%
total = 0

for m in range (5):
    m = m + 1
    num = int(input(f"Enter number {m} "))
    print(f"Number {m} is: {num}")
    total = total + num 
print(f"The total of 5 numbers is: {total}")
# Out:
# Number 1 is: 15
# Number 2 is: 26
# Number 3 is: 36
# Number 4 is: 38
# Number 5 is: 49
# The total of 5 numbers is: 164

# %% [markdown]
# 10. Write a Python program that:
#
# 1- Creates a list named clean_countries containing the following countries:
# [Bangladesh
# India
# Pakistan
# China]
#
# 2- Repeatedly asks the user to enter a country name.
#
# 3- Checks whether the entered country exists in the clean_countries list.
#
# 4-If the country is found in the list:
#
# Display the message:
#
# <country_name> is in clean countries list
#
# Stop the program.
#
# 5-If the country is not found, keep asking the user to enter another country.

# %%
clean_countries = ["Bangladesh", "India", "Pakistan","China"]
found = False

while found != True:
    country = input("Enter a name of country")
    for cleannest_country in clean_countries:
        if country == cleannest_country:
            print(f"{cleannest_country} is in clean country list")
            found = True
    if found != True:
        print(f"{country} is not in clean country list, Enter another name")
# Out:
# Nepal is not in clean country list, Enter another name
# Afghanistan is not in clean country list, Enter another name
# pakistan is not in clean country list, Enter another name
# Pakistan is in clean country list
